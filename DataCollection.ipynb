# %% [markdown]
# # Getting question via Gemini

# %% [markdown]
# ## **Loading Gemini**

# %%
# !pip install -q -U google-generativeai
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.2/142.2 kB 4.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.5/664.5 kB 47.3 MB/s eta 0:00:00

# %%
import google.generativeai as genai

# Used to securely store your API key
from google.colab import userdata

# %%
# Or use `os.getenv('GOOGLE_API_KEY')` to fetch an environment variable.
GOOGLE_API_KEY=userdata.get('GOOGLE_API_KEY')

genai.configure(api_key=GOOGLE_API_KEY)

# %%
for m in genai.list_models():
  if 'generateContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/gemini-1.0-pro
# models/gemini-1.0-pro-001
# models/gemini-1.0-pro-latest
# models/gemini-1.0-pro-vision-latest
# models/gemini-1.5-pro-latest
# models/gemini-pro
# models/gemini-pro-vision

# %%
safety_settings = [
  {
    "category": "HARM_CATEGORY_HARASSMENT",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_HATE_SPEECH",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_SEXUALLY_EXPLICIT",
    "threshold": "BLOCK_NONE"
  },
  {
    "category": "HARM_CATEGORY_DANGEROUS_CONTENT",
    "threshold": "BLOCK_NONE"
  },
]

model = genai.GenerativeModel(model_name="gemini-pro",
                              #generation_config=generation_config,
                              safety_settings=safety_settings)

# %% [markdown]
# ## **Book name + Summary**

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/Coding/AI-Builder/TheActualProject/DataCollection/booksummaries.txt",
                              header=None,sep="\t",
                              names=["ID", "Freebase ID", "Book Name", "Book Author", "Pub date","Genres","Summary"])
df = df[['ID', 'Book Name', 'Summary']]
df
# Out:
#              ID                                          Book Name  \
# 0           620                                        Animal Farm
# 1           843                                 A Clockwork Orange
# 2           986                                         The Plague
# 3          1756          An Enquiry Concerning Human Understanding
# 4          2080                               A Fire Upon the Deep
# ...         ...                                                ...
# 16554  36934824                                     Under Wildwood
# 16555  37054020                                  Transfer of Power
# 16556  37122323                                            Decoded
# 16557  37132319  America Again: Re-becoming The Greatness We Ne...
# 16558  37159503                                          Poor Folk
#
#                                                  Summary
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
# [16559 rows x 3 columns]

# %% [markdown]
# ## **Asking question & Collecting data**

# %% [markdown]
# ### **Test set: Unseen + seen (100-100)(head(202))**

# %%
# %%time

limited_df = df.head(202) #Trying smaller df first

data = []
error = []
for index, row in limited_df.iterrows():
  ID = row['ID']
  name = row['Book Name']
  summary = row['Summary']
  try:
    response = model.generate_content(f"""Book name: {name}
      Summary: {summary}
      If you were to ask some question to get a librarian to know what book you wanted to buy, without mentioning the title or any specific detail. (ask only 8 questions)""")
    data.append([ID, name, response.text])
  except Exception as e:
    print(f"Error for book {name}: {e}")
    error.append(name)

new_df = pd.DataFrame(data, columns=['ID', 'Book Name', 'Questions'])
new_df.to_csv('TESTUNCLEANbookquestions.csv', index=False)
# Out:
# Error for book A Clockwork Orange: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book The World According to Garp: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# CPU times: user 13.8 s, sys: 1.44 s, total: 15.3 s
# Wall time: 16min 27s

# %%
new_df
# Out:
#         ID                                  Book Name  \
# 0      620                                Animal Farm
# 1      986                                 The Plague
# 2     1756  An Enquiry Concerning Human Understanding
# 3     2080                       A Fire Upon the Deep
# 4     2152             All Quiet on the Western Front
# ..     ...                                        ...
# 195  58622                           Consider Phlebas
# 196  58665                                 Inversions
# 197  58888                         An Inspector Calls
# 198  58901                               Ender's Game
# 199  59375                           Titus Andronicus
#
#                                              Questions
# 0    1. Do you have any books that explore themes o...
# 1    1. Can you recommend a book that explores the ...
# 2    1. Can you recommend a book on the philosophy ...
# 3    1. Does the book explore the impact of technol...
# 4    1. Can you recommend a book that portrays the ...
# ..                                                 ...
# 195  1. Can you recommend a science fiction novel t...
# 196  1. Can you recommend a captivating historical ...
# 197  1. Is there a play that explores the themes of...
# 198  1. Is there a book that explores the complexit...
# 199  1. Could you recommend a play with a complex a...
#
# [200 rows x 3 columns]

# %%
error
# Out:
# ['A Clockwork Orange', 'The World According to Garp']

# %% [markdown]
# ### **Cleaning Test Set**

# %%
testdata = pd.read_csv('/content/drive/MyDrive/Coding/AI-Builder/TheActualProject/DataCollection/TESTUNCLEANbookquestions.csv')
testdf = pd.DataFrame(testdata)
testdf
# Out:
#         ID                                  Book Name  \
# 0      620                                Animal Farm
# 1      986                                 The Plague
# 2     1756  An Enquiry Concerning Human Understanding
# 3     2080                       A Fire Upon the Deep
# 4     2152             All Quiet on the Western Front
# ..     ...                                        ...
# 195  58622                           Consider Phlebas
# 196  58665                                 Inversions
# 197  58888                         An Inspector Calls
# 198  58901                               Ender's Game
# 199  59375                           Titus Andronicus
#
#                                              Questions
# 0    1. Do you have any books that explore themes o...
# 1    1. Can you recommend a book that explores the ...
# 2    1. Can you recommend a book on the philosophy ...
# 3    1. Does the book explore the impact of technol...
# 4    1. Can you recommend a book that portrays the ...
# ..                                                 ...
# 195  1. Can you recommend a science fiction novel t...
# 196  1. Can you recommend a captivating historical ...
# 197  1. Is there a play that explores the themes of...
# 198  1. Is there a book that explores the complexit...
# 199  1. Could you recommend a play with a complex a...
#
# [200 rows x 3 columns]

# %%
# %%time

data = []
for index, row in testdf.iterrows():
  ID = row['ID']
  name = row['Book Name']
  question = row['Questions']
  response = model.generate_content(f"""From these choices, give me one that most resembles a customer buying a book.
  {question}""")
  data.append([ID, name, response.text])

new_testdf = pd.DataFrame(data, columns=['ID', 'Book Name', 'Questions'])
new_testdf.to_csv('TESTCLEANbookquestions.csv', index=False)
# Out:
# CPU times: user 5.63 s, sys: 549 ms, total: 6.18 s
# Wall time: 5min 55s

# %%
new_testdf
# Out:
#         ID                                  Book Name  \
# 0      620                                Animal Farm
# 1      986                                 The Plague
# 2     1756  An Enquiry Concerning Human Understanding
# 3     2080                       A Fire Upon the Deep
# 4     2152             All Quiet on the Western Front
# ..     ...                                        ...
# 195  58622                           Consider Phlebas
# 196  58665                                 Inversions
# 197  58888                         An Inspector Calls
# 198  58901                               Ender's Game
# 199  59375                           Titus Andronicus
#
#                                              Questions
# 0    3. Which book features a character named Old M...
# 1    1. Can you recommend a book that explores the ...
# 2    1. Can you recommend a book on the philosophy ...
# 3    None of the choices most resembles a customer ...
# 4    1. Can you recommend a book that portrays the ...
# ..                                                 ...
# 195  1. Can you recommend a science fiction novel t...
# 196  1. Can you recommend a captivating historical ...
# 197  2. Do you have any books about a family gather...
# 198  1. Is there a book that explores the complexit...
# 199  1. Could you recommend a play with a complex a...
#
# [200 rows x 3 columns]

# %% [markdown]
# ## **Train set (run in vscode)**

# %%
# %%time

limited_df = df[202:]   #Get df after the test set

data = []
error = []
for index, row in limited_df.iterrows():
  ID = row['ID']
  name = row['Book Name']
  summary = row['Summary']
  try:
    response = model.generate_content(f"""Book name: {name}
      Summary: {summary}
      If you were to ask some question to get a librarian to know what book you wanted to buy, without mentioning the title or any specific detail. (ask only 8 questions)""")
    data.append([ID, name, response.text])
  except Exception as e:
    print(f"Error for book {name}: {e}")
    error.append(name)

new_df = pd.DataFrame(data, columns=['ID', 'Book Name', 'Question'])
new_df.to_csv('TRAINbookquestions.csv', index=False)
# Out:
# Error for book Choke: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Lost Girls: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book The Tale of Genji: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book East of Eden: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Equus: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Fanny Hill: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Trainspotting: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Angela's Ashes: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book The Jealous God: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Myra Breckinridge: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Joy: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Rubyfruit Jungle: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Perfume: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book The Eye of Argon: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Oryx and Crake: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Speak: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book Viper in the Fist: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book The Edible Woman: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.
# Error for book A Time to Kill: The `response.parts` quick accessor only works for a single candidate, but none were returned. Check the `response.prompt_feedback` to see if the prompt was blocked.

# %% [markdown]
# ## **Making it asynchronous(didn't work:💀)**

# %%
import asyncio

limited_df = df.head(10)

# Define a coroutine to generate content for a single book
async def generate_content(name, summary):
  try:
    result = await model.generate_content_async(f"""Book name: {name}
      Summary: {summary}
      From this information if you were to buy this book but you don't know the name of this book. How would you ask questions to get other people to know what book you wanted.(You can ask only 8 question)""")
    return [name, result.text]
  except Exception as e:
    print(f"Error for book {name}: {e}")
    return [name, None]

# Create a list of coroutines
coroutines = [generate_content(name, summary) for name, summary in zip(limited_df['Book Name'], limited_df['Summary'])]

# Run the coroutines concurrently using asyncio.gather
new_data = await asyncio.gather(*coroutines)

# Filter out any errors
new_df = pd.DataFrame([d for d in new_data if d[1] is not None], columns=['Book Name', 'Summary'])
# Out:
# Error for book Animal Farm: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book A Clockwork Orange: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book The Plague: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book An Enquiry Concerning Human Understanding: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book A Fire Upon the Deep: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book All Quiet on the Western Front: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book A Wizard of Earthsea: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book Anyone Can Whistle: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book Blade Runner 3: Replicant Night: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book Blade Runner 2: The Edge of Human: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>

# %%
import asyncio

limited_df = df.head(10)
sem = asyncio.Semaphore(10)

async def generate_content(name, summary):
  async with sem:
    try:
      result = await model.generate_content_async(f"""Book name: {name}
        Summary: {summary}
        From this information if you were to buy this book but you don't know the name of this book. How would you ask questions to get other people to know what book you wanted.(You can ask only 8 question)""")
      return [name, result.text]
    except Exception as e:
      print(f"Error for book {name}: {e}")
      return [name, None]

async def main():
  tasks = [generate_content(name, summary) for name, summary in zip(limited_df['Book Name'], limited_df['Summary'])]
  result = await asyncio.gather(*tasks)
  new_df = pd.DataFrame([d for d in result if d[1] is not None], columns=['Book Name', 'Summary'])

await main()
# Out:
# Error for book Animal Farm: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book A Clockwork Orange: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book The Plague: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book An Enquiry Concerning Human Understanding: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book A Fire Upon the Deep: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book All Quiet on the Western Front: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book A Wizard of Earthsea: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book Anyone Can Whistle: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book Blade Runner 3: Replicant Night: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>
# Error for book Blade Runner 2: The Edge of Human: Unexpected type of call <class 'google.ai.generativelanguage_v1beta.types.generative_service.GenerateContentResponse'>

# %%
new_df
# Out:
#                                    Book Name  \
# 0                                Animal Farm
# 1                                 The Plague
# 2  An Enquiry Concerning Human Understanding
# 3                       A Fire Upon the Deep
# 4             All Quiet on the Western Front
# 5                       A Wizard of Earthsea
# 6                         Anyone Can Whistle
# 7            Blade Runner 3: Replicant Night
# 8          Blade Runner 2: The Edge of Human
#
#                                              Summary
# 0  1. Is there a book where animals rebel against...
# 1  1. Is there a book where a town is quarantined...
# 2  1. Is it a philosophy book?\n2. Does it discus...
# 3  1. Can you recommend a science fiction novel a...
# 4  1. Can you recommend a book that portrays the ...
# 5  1. Is there a novel that features a young boy ...
# 6  1. Can you recommend a play set in an imaginar...
# 7  1. Is it a sci-fi book set in a futuristic wor...
# 8  1. Is there a book that continues the story of...
